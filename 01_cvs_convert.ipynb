# %%
# import csv

# # 입력 CSV 파일명
# input_file_name = "mydata.csv"

# # 출력 CSV 파일명
# output_file_name = "output.csv"

# # 원하는 열(항목)의 인덱스 (0부터 시작)
# desired_columns = ['지점명', '승주대상', '합계']  # 예: 첫 번째 열, 세 번째 열, 네 번째 열

# # CSV 파일 열기 및 데이터 추출
# #with open(input_file_name, mode='r', newline='') as input_file, open(output_file_name, mode='w', newline='') as output_file:
# with open(input_file_name, mode='r', encoding='utf-8', errors='ignore', newline='') as input_file:
# # 나머지 코드는 그대로 유지

#     reader = csv.reader(input_file)
#     writer = csv.writer(output_file)
    
#     # 헤더(열 이름) 추출 및 필요한 열만 선택
#     header = next(reader)
#     selected_header = [header[i] for i in desired_columns]
#     writer.writerow(selected_header)
    
#     # 데이터 추출 및 필요한 열만 선택하여 새로운 파일에 쓰기
#     for row in reader:
#         selected_row = [row[i] for i in desired_columns]
#         writer.writerow(selected_row)

# print(f"{output_file_name} 파일이 생성되었습니다.")

import csv
import chardet

# CSV 파일명
file_name = "mydata.csv"

# 파일 인코딩 자동 감지
with open(file_name, 'rb') as rawdata:
    result = chardet.detect(rawdata.read())
file_encoding = result['encoding']

# CSV 파일 열기
with open(file_name, mode='r', encoding=file_encoding, newline='') as file:
    reader = csv.reader(file)
    
    # 첫 번째 행을 열 이름으로 읽기
    column_names = next(reader)
    
    # 원하는 열(항목)의 이름
    desired_columns = ['지점명', '승주대상', '합계']  # 실제 열 이름으로 변경
    
    # 열(항목)의 인덱스 찾기
    column_indices = [column_names.index(column) for column in desired_columns]
    
    # CSV 파일을 다시 열어서 데이터를 출력
    file.seek(0)  # 파일을 처음으로 되돌림
    next(reader)  # 첫 번째 행(열 이름)을 건너뛰기
    
    # 원하는 열만 출력
    for row in reader:
        selected_values = [row[i] for i in column_indices]
        print('\t'.join(selected_values))  # 열 사이에 탭(Tab)을 넣어 출력

# CSV 파일 닫기
file.close()
# Out:
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	1	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	1	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	1	1
# HNS강남지점	0	1
# HNS강남지점	1	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	1	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	0	1
# HNS강남지점	1	1
# ...
