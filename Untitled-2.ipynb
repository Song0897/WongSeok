# %%
# # 내업무 자동화  https://github.com/


# import pyodbc

# # 데이터베이스 연결 정보 설정
# server = '210.180.103.100'  # SQL Server의 주소 또는 이름
# database = '210.180.103.100'  # 연결할 데이터베이스 이름
# username = 'hns_prm'  # SQL Server 사용자명
# password = '@tjqltmrhksflxla1'  # 사용자의 비밀번호

# # 연결 문자열 생성
# connection_string = f'DRIVER=ODBC Driver 17 for SQL Server;SERVER={server};DATABASE={database};UID={username};PWD={password}'

# # 데이터베이스 연결
# try:
#     connection = pyodbc.connect(connection_string)
#     cursor = connection.cursor()

#     # SQL 쿼리 파일 읽기
#     with open('pol_20230911.sql', 'r') as sql_file:
#         sql_query = sql_file.read()

#     # SQL 쿼리 실행
#     cursor.execute(sql_query)

#     # 결과 가져오기
#     rows = cursor.fetchall()
    
#     # 결과 출력 예제
#     for row in rows:
#         print(row)

#     # 연결 종료
#     cursor.close()
#     connection.close()

# except Exception as e:
#     print(f"Error: {str(e)}")

#################

import os
from pathlib import Path
import pyodbc

# # 현재 작업 디렉토리 확인
# current_directory = os.getcwd()
# print("현재 작업 디렉토리:", current_directory)

# "ABC.sql" 파일 경로 설정 (os 모듈 사용)
sql_file_path = os.path.join(current_directory, "pol_20230911.sql")

# 또는 "ABC.sql" 파일 경로 설정 (Pathlib 모듈 사용, Python 3.4 이상)
# script_directory = Path(__file__).resolve().parent
# sql_file_path = script_directory / "ABC.sql"

# 연결 설정
server = '210.180.103.100'  # SQL Server의 주소 또는 이름
database = 'QMSKPI'  # 연결할 데이터베이스 이름
username = 'hns_prm'  # SQL Server 사용자명
password = '@tjqltmrhksflxla1'  # 사용자의 비밀번호

# 연결 문자열 생성
connection_string = f'DRIVER=ODBC Driver 13 for SQL Server;SERVER={server};DATABASE={database};UID={username};PWD={password}'

# 데이터베이스 연결
try:
    connection = pyodbc.connect(connection_string)
    cursor = connection.cursor()

    # SQL 파일 읽기
    # with open(sql_file_path, 'r', encoding='utf-8', errors='ignore') as sql_file:
    #     sql_query = sql_file.read()
    
    with open(sql_file_path, 'r', encoding='utf-8', errors='ignore') as sql_file:
        sql_query = sql_file.read()
    
    # SQL 쿼리 실행
    cursor.execute(sql_query)

    # 결과 가져오기
    rows = cursor.fetchall()

    # 결과 출력
    for row in rows:
        print(row)

    # 연결 종료
    cursor.close()
    connection.close()

except Exception as e:
    print(f"Error: {str(e)}")
# Out:
# Error: ('42000', '[42000] [Microsoft][ODBC Driver 13 for SQL Server][SQL Server]\',\' 근처의 구문이 잘못되었습니다. (102) (SQLExecDirectW); [42000] [Microsoft][ODBC Driver 13 for SQL Server][SQL Server]개체 또는 열 이름이 없거나 비어 있습니다. SELECT INTO 문의 각 열에 이름이 있는지 확인하십시오. 다른 문의 경우에는 빈 별칭이 있는지 확인하십시오. 별칭은 "" 또는 []로 정의할 수 없습니다. 별칭을 올바른 이름으로 변경하십시오. (1038); [42000] [Microsoft][ODBC Driver 13 for SQL Server][SQL Server]\'ð\' 근처의 구문이 잘못되었습니다. (102); [42000] [Microsoft][ODBC Driver 13 for SQL Server][SQL Server]개체 또는 열 이름이 없거나 비어 있습니다. SELECT INTO 문의 각 열에 이름이 있는지 확인하십시오. 다른 문의 경우에는 빈 별칭이 있는지 확인하십시오. 별칭은 "" 또는 []로 정의할 수 없습니다. 별칭을 올바른 이름으로 변경하십시오. (1038); [42000] [Microsoft][ODBC Driver 13 for SQL Server][SQL Server]개체 또는 열 이름이 없거나 비어 있습니다. SELECT INTO 문의 각 열에 이름이 있는지 확인하십시오. 다른 문의 경우에는 빈 별칭이 있는지 확인하십시오. 별칭은 "" 또는 []로 정의할 수 없습니다. 별칭을 올바른 이름으로 변경하십시오. (1038); [42000] [Microsoft][ODBC Driver 13 for SQL Server][SQL Server]개체 또는 열 이름이 없거나 비어 있습니다. SELECT INTO 문의 각 열에 이름이 있는지 확인하십시오. 다른 문의 경우에는 빈 별칭이 있는지 확인하십시오. 별칭은 ""
# ...
